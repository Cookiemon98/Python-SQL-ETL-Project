# %%
# import libraries
#!pip install kaggle
# import kaggle

# %%
# download dataset using kaggle api
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# ...
#   0%|          | 0.00/200k [00:00<?, ?B/s]
# 100%|##########| 200k/200k [00:00<00:00, 370MB/s]

# %%
# To rename file with its extension
# import os

# os.rename("orders.csv", "orders.zip")

# %%
# in case a zip file is downloaded through the api use the below code to extract it
import zipfile

# This will download the file that was downloaded in the folder from which the jupyter notebook was launched
# if you for taking data from another location, you have to specify the full path. 
zip_ref = zipfile.ZipFile('orders.zip')

# Give the location at which you want to extract the data at
zip_ref.extractall("D:\Python\SQL+Pyhon project") 
zip_ref.close()
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\P'
# <>:7: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\jatin\AppData\Local\Temp\ipykernel_5656\1151596198.py:7: SyntaxWarning: invalid escape sequence '\P'
#   zip_ref.extractall("D:\Python\SQL+Pyhon project")

# %%
# Checking the encoding of the file in case of any error
# import chardet

# # Detect Encoding
# with open('orders.csv','rb') as f:
#     result = chardet.detect(f.read(100000))

# print(result['encoding'])

# If not able to see the file correctly, then try this to forcefully change the encoding 
# with open('orders.csv', 'rb') as f:
#     content = f.read()

# # Try decoding with fallback
# decoded = content.decode('latin1', errors='replace')

# # Write back a cleaned file
# with open('orders2.csv', 'w', encoding='utf-8') as f:
#     f.write(decoded)

# # Load it
# df = pd.read_csv('orders.csv')

# %%
# read data from the file and handle the null values
import pandas as pd
df = pd.read_csv('orders.csv', na_values=['Not Available', 'unknown']) # Replacing odd values with nan
df.head(20) # The above fixes the issue with incorrect values
# Out:
#     Order Id  Order Date       Ship Mode      Segment        Country  \
# 0          1  2023-03-01    Second Class     Consumer  United States
# 1          2  2023-08-15    Second Class     Consumer  United States
# 2          3  2023-01-10    Second Class    Corporate  United States
# 3          4  2022-06-18  Standard Class     Consumer  United States
# 4          5  2022-07-13  Standard Class     Consumer  United States
# 5          6  2022-03-13             NaN     Consumer  United States
# 6          7  2022-12-28  Standard Class     Consumer  United States
# 7          8  2022-01-25  Standard Class     Consumer  United States
# 8          9  2023-03-23             NaN     Consumer  United States
# 9         10  2023-05-16  Standard Class     Consumer  United States
# 10        11  2023-03-31             NaN     Consumer  United States
# 11        12  2023-12-25             NaN     Consumer  United States
# 12        13  2022-02-11  Standard Class     Consumer  United States
# ...

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
# renaming column names; making them lower case and replacing spaces with an underscore

df.rename(columns={'Order Id':'order_id', 'City':'city'}) #This is one method but its time consuming in case more columns are considered for change.
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(" ", "_")

# the above is a better approach when dealing with multiple fields and the opertion to be performed on them is the same

# %%
df.head()
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
# deriving new columns for discount, sale price and profit

df['discount'] = df['list_price']*df['discount_percent']*0.01
df['sale_price'] = df['list_price']-df['discount']
df['profit'] = df['sale_price'] - df['cost_price']

df.head()
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
# Data Types conversion
df['order_date'] = pd.to_datetime(df['order_date'],format="%Y-%m-%d")

# %%
# dropping unnecessary columns

df.drop(columns=['list_price', 'cost_price', 'discount_percent'], inplace=True)
# inplace=True is used so that the changes are made directly to the dataframe.

# %%
df.dtypes
# Out:
# order_id                 int64
# order_date      datetime64[ns]
# ship_mode               object
# segment                 object
# country                 object
# city                    object
# state                   object
# postal_code              int64
# region                  object
# category                object
# sub_category            object
# product_id              object
# quantity                 int64
# discount               float64
# sale_price             float64
# profit                 float64
# dtype: object

# %%
# installing mysql library
# pip install pandas mysql-connector-python sqlalchemy

from sqlalchemy import create_engine

user = "root"
password = "Jatin@2097"
host = "localhost"
port = 3306
database = "sql_python_project"

# Note : Make sure to URL-encode special characters in the password
from urllib.parse import quote_plus
encoded_password = quote_plus(password)


# Create engine
engine = create_engine(f"mysql+mysqlconnector://{user}:{encoded_password}@{host}:{port}/{database}")

# %%
df.to_sql(name='df_orders', con=engine, if_exists='append', index=False)
# Use append and create an empty table in the database, as it saves memory. Which is then appended instead of replaced, which creates a table with max data
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\mysql\connector\connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
#     779 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Duplicate entry '1' for key 'df_orders.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# ...
